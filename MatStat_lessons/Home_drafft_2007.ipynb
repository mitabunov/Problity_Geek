# %%
import numpy as np
import matplotlib.pyplot as plt
import decimal
import numpy as np

# %%
numpy_array_1 = np.array([10,10,10 ])
numpy_array_2 = np.array([0,0,-10])

# %%
np.sum([numpy_array_1 + numpy_array_2])
# Out:
# 20

# %% [markdown]
# Напишите код на Python, реализующий построение графиков:окружности,эллипса,гиперболы

# %%
an = np.linspace(0, 2 * np.pi, 100)
fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(4 * np.cos(an)*-2, 3 * np.sin(an))
axs[0, 0].set_title('not equal, looks like ellipse', fontsize=10)

axs[0, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[0, 1].axis('equal')
axs[0, 1].set_title('equal, looks like circle', fontsize=10)

xmin = -20
xmax = 20
dx = 0.5

xlist = np.around(np.arange(20, -20, 0.5), decimals=2)

ylist = 1 / xlist

axs[1, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[1, 1].set_aspect('equal', 'box')
axs[1, 1].set_title('still a circle, auto-adjusted data limits', fontsize=10)

fig.tight_layout()

plt.show()

# %%
# ?set_aspect
# Out:
# Object `set_aspect` not found.

# %% [markdown]
# Гипербола

# %%
xmin = -20
xmax = 20
dx = 0.5

xlist = np.around(np.arange(xmin, xmax, dx), decimals=2)

ylist = 1 / xlist

plt.plot(ylist)
plt.show()
# Out:
# /home/mikhail/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide

# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
import numpy as np

# от -5 до 2 сделать 100 точек.Чем больше точек, тем точнее график.
x = np.linspace(-2, 5, 100)
# y1...y4 - линии одного графика, для каждой линии свой набор точек.

k = 1
a = 2
b = 30
x1 = x - a


y1 = x**3 + 5*x**2 + 10
y2 = 3*x**2 + 10*x
y3 = 6*x + 10
y4 = 5*x**2 + 10
y5 = 10 - x1**3 + b
y6 = 1/x

# будет 1 график, на нем 4 линии:
fig, ax = plt.subplots()
# функция y1(x), синий, надпись y(x)
ax.plot(x, y1, color="blue", label="голубая линия")
# функция y2(x), красный, надпись y'(x)
ax.plot(x,y2, color="red", label="красная линия")
# функция y3(x), зеленый, надпись y''(x)
ax.plot(x, y3, color="green", label="зелёная линия")
# функция y3(x), зеленый, надпись y''(x)
ax.plot(x, y4, color="black", label="черная линия")

ax.plot(x, y6, color="pink", label="розовая")

plt.Circle ((1,-6), radius = 5, fill =True)
plt.grid()
plt.show()
# подпись у горизонтальной оси х
ax.set_xlabel("x")
# подпись у вертикальной оси y
ax.set_ylabel("y")
# показывать условные обозначения
ax.legend()

'''
Тут нужно сделать выбор в пользу одного действия. Либо вы показываете на окне 
векторный график, либо записываете график в картинку png
'''
#показать рисунок
plt.show()

# %%
import math

# %%
x =[]
y1 = []
y2 = []
p = 7

for i in range(1000):
    x_= i/1000
    x.append(x_)
    y1.append(math.sqrt(p**2+x_))
    y2.append(-math.sqrt(p**3+x_))
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
from mpl_toolkits.mplot3d import Axes3D
from pylab import *

# %%
fig = figure()
ax = Axes3D(fig)

X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = 4*X - 9*Y

ax.plot_wireframe(X,Y,Z)
ax.plot_wireframe(X,Y,Z-20)
ax.plot_wireframe(X**2,Y*3,Z-20)

show()
